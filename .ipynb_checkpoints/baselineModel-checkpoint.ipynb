# %%
import pandas as pd
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Images are 28 by 28 pixels
#
# Labels:
#
# 0 T-shirt/top
# 1 Trouser
# 2 Pullover
# 3 Dress
# 4 Coat
# 5 Sandal
# 6 Shirt
# 7 Sneaker
# 8 Bag
# 9 Ankle boot

# %%
from fashionData import *

# %%
train = FashionData('data/fashion-mnist_train.csv')
print(train.labels,train.images.shape)
# Out:
# tensor([2, 9, 6,  ..., 8, 8, 7]) torch.Size([60000, 1, 28, 28])

# %%
plt.imshow(train.images[0,0,:,:])
plt.show()

# %%
sweaters = train.images[train.labels == 8,0,:,:]
sweaters_avg = torch.sum(sweaters, dim=0)/sweaters.shape[0]

plt.imshow(sweaters_avg)
plt.show()

# %%
baseline = FashionBaselineModel(train.labels, train.images)
# Out:
# Training set Accuracy:  0.60985
# Performance for target label 0.0 0.6276666666666667
# Performance for target label 1.0 0.9421666666666667
# Performance for target label 2.0 0.24266666666666667
# Performance for target label 3.0 0.7038333333333333
# Performance for target label 4.0 0.6456666666666667
# Performance for target label 5.0 0.5225
# Performance for target label 6.0 0.17366666666666666
# Performance for target label 7.0 0.8978333333333334
# Performance for target label 8.0 0.5341666666666667
# Performance for target label 9.0 0.8083333333333333

# %%
test = FashionData('data/fashion-mnist_test.csv')

# %%
baseline.score_on_data_set(test.labels,test.images)
# Out:
# (0.6081,
#  {0.0: 0.622,
#   1.0: 0.943,
#   2.0: 0.251,
#   3.0: 0.686,
#   4.0: 0.657,
#   5.0: 0.528,
#   6.0: 0.166,
#   7.0: 0.885,
#   8.0: 0.552,
#   9.0: 0.791})
